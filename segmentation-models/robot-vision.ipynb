# %%
# !from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/
# Out:
# /content/drive/MyDrive/Github

# %%
# username = 'ahamboeck'
# repository = 'Robot-Traversability-with-Image-Segmentation'
# git_token = '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'

# %%
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# fatal: destination path 'Robot-Traversability-with-Image-Segmentation' already exists and is not an empty directory.

# %%
# %ls
# Out:
# robot-vision.ipynb
